# %% [markdown]
# https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data

# %% [markdown]
# ### Loading the Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Henrique\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Importing the dataset

# %%
pd.set_option('display.max_columns', None)
data = pd.read_csv(r'C:\Users\Henrique\Desktop\0Machine Learning & Deep Learning Projects for Beginners (TutsNode.net) 2023\02 - Project 1 Breast Cancer Detection/data.csv')

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ### Data exploration

# %% [markdown]
# ### Checking the shape (lines, columns) of the data

# %%
print(f'There are {data.shape[0]} lines and {data.shape[1]} columns in this dataset.')
# Out:
# There are 569 lines and 33 columns in this dataset.

# %% [markdown]
# ### Checking the column name, non-null count and Dtypes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# ### Verifying the percentage of missing values

# %%
def percent_missing(df):
    missing = df.isnull().sum()
    percent_missing = missing / data.shape[0] * 100
    print(percent_missing)

# %%
percent_missing(data)
# Out:
# id                           0.0
# diagnosis                    0.0
# radius_mean                  0.0
# texture_mean                 0.0
# perimeter_mean               0.0
# area_mean                    0.0
# smoothness_mean              0.0
# compactness_mean             0.0
# concavity_mean               0.0
# concave points_mean          0.0
# symmetry_mean                0.0
# fractal_dimension_mean       0.0
# radius_se                    0.0
# texture_se                   0.0
# perimeter_se                 0.0
# area_se                      0.0
# smoothness_se                0.0
# compactness_se               0.0
# concavity_se                 0.0
# concave points_se            0.0
# symmetry_se                  0.0
# fractal_dimension_se         0.0
# radius_worst                 0.0
# texture_worst                0.0
# perimeter_worst              0.0
# area_worst                   0.0
# smoothness_worst             0.0
# compactness_worst            0.0
# ...

# %% [markdown]
# ### Checking the missing values visually.
# - Red values represent missing values.
# - Blue values represent non-missing data.

# %%
def missing_heatmap(df):
    plt.figure(figsize=(20,10))
    sns.heatmap(df.isnull(), cmap='coolwarm')
    plt.show();

# %%
missing_heatmap(data)

# %% [markdown]
# ### Selecting all columns with categorical variables

# %%
cat_cols = data.select_dtypes(include=["object"]).columns
print(cat_cols)
# Out:
# Index(['diagnosis'], dtype='object')

# %%
total_num = len(cat_cols)
print(f'Total columns with categorical variables: {total_num}')
# Out:
# Total columns with categorical variables: 1

# %% [markdown]
# ### Selecting all columns with numerical variables

# %%
num_cols = data.select_dtypes(include=["int64","float64"]).columns
print(num_cols)
# Out:
# Index(['id', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
total_cat = len(num_cols)
print(f'Total columns with categorical variables: {total_cat}')
# Out:
# Total columns with categorical variables: 32

# %%
# Statistical summaty

data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %% [markdown]
# # 3. Data Preparation
#
# - In the "Data Preparation" phase of CRISP-DM, the goal is to perform necessary transformations on the data so that they can be used in the modeling phase.
# - This includes handling missing data, scaling normalization, selecting relevant variables, and other preparation steps.

# %% [markdown]
# ### Dealing with the missing values

# %%
print(f'Are there any null values? {data.isnull().values.any()}')
# Out:
# Are there any null values? True

# %%
print(f'How many null values? {data.isnull().values.sum()}')
# Out:
# How many null values? 569

# %%
null_col = data.columns[data.isnull().any()]
print(f'Which columns have null values? {null_col}')
# Out:
# Which columns have null values? Index(['Unnamed: 32'], dtype='object')

# %%
print(f'How many columns with null values? {len(null_col)}')
# Out:
# How many columns with null values? 1

# %%
# All values of this columns are null values
data['Unnamed: 32'].count()
# Out:
# 0

# %% [markdown]
# ### Here we are going to delete the 'Unnamed: 32' column that has all null values.

# %%
data.drop('Unnamed: 32', axis=1, inplace=True)

# %%
data.shape
# Out:
# (569, 32)

# %%
print(f'Are there any null values? {data.isnull().values.any()}')
# Out:
# Are there any null values? False

# %%
percent_missing(data)
# Out:
# id                         0.0
# diagnosis                  0.0
# radius_mean                0.0
# texture_mean               0.0
# perimeter_mean             0.0
# area_mean                  0.0
# smoothness_mean            0.0
# compactness_mean           0.0
# concavity_mean             0.0
# concave points_mean        0.0
# symmetry_mean              0.0
# fractal_dimension_mean     0.0
# radius_se                  0.0
# texture_se                 0.0
# perimeter_se               0.0
# area_se                    0.0
# smoothness_se              0.0
# compactness_se             0.0
# concavity_se               0.0
# concave points_se          0.0
# symmetry_se                0.0
# fractal_dimension_se       0.0
# radius_worst               0.0
# texture_worst              0.0
# perimeter_worst            0.0
# area_worst                 0.0
# smoothness_worst           0.0
# compactness_worst          0.0
# concavity_worst            0.0
# concave points_worst       0.0
# ...

# %% [markdown]
# ### Here we will print the column name and its respective Dtype. Below, we will display the column name with the first value.

# %%
print(data.dtypes)
print('-'*50)
print(data.iloc[0])
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %% [markdown]
# ### Checking the correlations of the columns with the target variable 'diagnosis'.
# - To do this, we will create a copy of the dataframe and remove the target column.

# %%
data_copy = data.copy()
data2 = data.drop('diagnosis', axis=1)

# %%
data_copy.shape
# Out:
# (569, 32)

# %%
data2.shape
# Out:
# (569, 31)

# %%
def corrwith(df1, df2, column):
    df1.corrwith(df2[column]).plot.bar(
    figsize=(15,10), title=f'Level of correlation with {column}', grid=True
    )

# %%
for index, value in enumerate(data_copy['diagnosis']):
    if value == 'B':
        data_copy.at[index, 'diagnosis'] = 0.0
    elif value == 'M':
        data_copy.at[index, 'diagnosis'] = 1.0

data_copy['diagnosis'] = data_copy['diagnosis'].astype('float64')

def corrwith(df1, df2, column):
    df1.corrwith(df2[column]).plot.bar(
    figsize=(15,10), title=f'Level of correlation with {column}', grid=True
    )

# %%
corrwith(data2, data_copy, 'diagnosis')

# %%
def heatmap(df):
    plt.figure(figsize=(30,30))
    sns.heatmap(df.corr(), cmap='coolwarm', annot=True, linewidth=1)

# %%
heatmap(data)

# %% [markdown]
# As we can see, we have several highly correlated columns. For now, we will use all of them. In the end, we will remove them and assess the performance of our model.
#
# Highly correlated columns:
# - 'radius_mean' with 'perimeter_mean' - 0.997855
# - 'radius_mean' with 'area_mean' - 0.987357
# - 'perimeter_mean' with 'area_mean' - 0.986507
# - 'compactness_mean' with 'concavity_mean' - 0.883121
# - 'concavity_mean' with 'concave points_mean' - 0.921391
# - 'radius_se' with 'perimeter_se' - 0.972794
# -  'radius_se' with 'area_se' - 0.951830
# - 'area_se' with 'perimeter_se' - 0.937655
# - 'radius_worst' with 'perimeter_worst' - 0.993708
# - 'area_worst' with 'radius_worst' - 0.984015
# - 'perimeter_worst' with 'area_worst' - 0.977578
# - 'compactness_worst' with 'concavity_worst' - 0.892261
# - 'concavity_worst' with 'concave points_worst' - 0.855434

# %% [markdown]
# ## Let's analyze each column and decide whether we will remove the outliers or not.
# - If we remove outliers from all columns, we will lose a lot of data. Therefore, I will choose to remove outliers only from the two columns that have the most outliers.

# %%
def how_many_outliers(df, column):
    inf_lim, sup_lim = limits(df[column])
    inf = df.loc[df[column] < inf_lim].shape[0]
    sup = df.loc[df[column] > sup_lim].shape[0]
    total = inf + sup
    print(f'There are about {inf} outliers below the lower limit.')
    print(f'There are about {sup} outliers above the upper limit.')
    print(f'There are about {total} outliers in total.')

# %%
def limits(column):
    q1 = column.quantile(0.25)
    q3 = column.quantile(0.75)
    iqr = q3 - q1
    return q1 - 1.5 * iqr, q3 + 1.5 * iqr

def boxplot(column):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(15, 5)
    sns.boxplot(x=column, ax=ax1)
    ax2.set_xlim(limits(column))
    sns.boxplot(x=column, ax=ax2)

def displot(column):
    dis = sns.displot(column, kde=True)
    dis.fig.set_size_inches(12,5)

def barplot():
    pass

def countplot(column, x_tick_rotation=False, x_rotation=90):
    print(column.value_counts())
    plt.figure(figsize=(15,5))
    ax = sns.countplot(x=column)
    if x_tick_rotation:
        ax.tick_params(axis='x', rotation=x_rotation)

def how_many_outliers(df, column):
    inf_lim, sup_lim = limits(df[column])
    inf = df.loc[df[column] < inf_lim].shape[0]
    sup = df.loc[df[column] > sup_lim].shape[0]
    total = inf + sup
    return inf, sup, total
    

def remove_outliers(df, column):
    n_of_rows = df.shape[0]
    inf_lim, sup_lim = limits(df[column])
    df = df.loc[(df[column] >= inf_lim) & (df[column] <= sup_lim), :]
    removed_rows = n_of_rows - df.shape[0]
    return df, removed_rows

# %% [markdown]
# ### 'id'
# - Let's eliminate the 'id' column. It will be irrelevant for our model.

# %%
data.drop('id', axis=1, inplace=True)
data.shape
# Out:
# (569, 31)

# %% [markdown]
# ### 'diagnosis'
# - The diagnosis of breast tissues (M = malignant, B = benign)

# %%
countplot(data['diagnosis'])
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# - This is our target.

# %% [markdown]
# ### 'radius_mean'
# - mean of distances from center to points on the perimeter

# %%
print(limits(data['radius_mean']))
inf, sup, total = how_many_outliers(data,'radius_mean')
print(total)
boxplot(data['radius_mean'])
displot(data['radius_mean'])
# Out:
# (5.579999999999999, 21.9)
# 14

# %% [markdown]
# ### 'texture_mean'
# - standard deviation of gray-scale values

# %%
print(limits(data['texture_mean']))
how_many_outliers(data,'texture_mean')
boxplot(data['texture_mean'])
displot(data['texture_mean'])
# Out:
# (7.725000000000003, 30.244999999999997)
# There are about 0 outliers below the lower limit.
# There are about 7 outliers above the upper limit.
# There are about 7 outliers in total.

# %% [markdown]
# ### 'perimeter_mean'
# - mean size of the core tumor

# %%
print(limits(data['perimeter_mean']))
how_many_outliers(data,'perimeter_mean')
boxplot(data['perimeter_mean'])
displot(data['perimeter_mean'])
# Out:
# (31.775000000000013, 147.49499999999998)
# There are about 0 outliers below the lower limit.
# There are about 13 outliers above the upper limit.
# There are about 13 outliers in total.

# %% [markdown]
# ### 'area_mean'
# -

# %%
print(limits(data['area_mean']))
how_many_outliers(data,'area_mean')
boxplot(data['area_mean'])
displot(data['area_mean'])
# Out:
# (-123.30000000000001, 1326.3000000000002)
# There are about 0 outliers below the lower limit.
# There are about 25 outliers above the upper limit.
# There are about 25 outliers in total.

# %% [markdown]
# ### 'smoothness_mean'
# - mean of local variation in radius lengths

# %%
print(limits(data['smoothness_mean']))
how_many_outliers(data,'smoothness_mean')
boxplot(data['smoothness_mean'])
displot(data['smoothness_mean'])
# Out:
# (0.057975, 0.133695)
# There are about 1 outliers below the lower limit.
# There are about 5 outliers above the upper limit.
# There are about 6 outliers in total.

# %% [markdown]
# ### 'compactness_mean'
# - mean of perimeter^2 / area - 1.0

# %%
print(limits(data['compactness_mean']))
how_many_outliers(data,'compactness_mean')
boxplot(data['compactness_mean'])
displot(data['compactness_mean'])
# Out:
# (-0.03329999999999997, 0.22861999999999996)
# There are about 0 outliers below the lower limit.
# There are about 16 outliers above the upper limit.
# There are about 16 outliers in total.

# %% [markdown]
# ### 'concavity_mean'
# - mean of severity of concave portions of the contour

# %%
print(limits(data['concavity_mean']))
how_many_outliers(data,'concavity_mean')
boxplot(data['concavity_mean'])
displot(data['concavity_mean'])
# Out:
# (-0.12215000000000001, 0.28241000000000005)
# There are about 0 outliers below the lower limit.
# There are about 18 outliers above the upper limit.
# There are about 18 outliers in total.

# %% [markdown]
# ### 'concave points_mean'
# - mean for number of concave portions of the contour

# %%
print(limits(data['concave points_mean']))
how_many_outliers(data,'concave points_mean')
boxplot(data['concave points_mean'])
displot(data['concave points_mean'])
# Out:
# (-0.060224999999999994, 0.15453499999999998)
# There are about 0 outliers below the lower limit.
# There are about 10 outliers above the upper limit.
# There are about 10 outliers in total.

# %% [markdown]
# ### 'symmetry_mean'
# -

# %%
print(limits(data['symmetry_mean']))
how_many_outliers(data,'symmetry_mean')
boxplot(data['symmetry_mean'])
displot(data['symmetry_mean'])
# Out:
# (0.11119999999999995, 0.24640000000000006)
# There are about 1 outliers below the lower limit.
# There are about 14 outliers above the upper limit.
# There are about 15 outliers in total.

# %% [markdown]
# ### 'fractal_dimension_mean'
# - mean for "coastline approximation" - 1

# %%
print(limits(data['fractal_dimension_mean']))
how_many_outliers(data,'fractal_dimension_mean')
boxplot(data['fractal_dimension_mean'])
displot(data['fractal_dimension_mean'])
# Out:
# (0.045070000000000006, 0.07874999999999999)
# There are about 0 outliers below the lower limit.
# There are about 15 outliers above the upper limit.
# There are about 15 outliers in total.

# %% [markdown]
# ### 'radius_se'
# - standard error for the mean of distances from center to points on the perimeter

# %%
print(limits(data['radius_se']))
how_many_outliers(data,'radius_se')
boxplot(data['radius_se'])
displot(data['radius_se'])
# Out:
# (-0.13735000000000003, 0.84865)
# There are about 0 outliers below the lower limit.
# There are about 38 outliers above the upper limit.
# There are about 38 outliers in total.

# %% [markdown]
# ### 'texture_se'
# - standard error for standard deviation of gray-scale values

# %%
print(limits(data['texture_se']))
how_many_outliers(data,'texture_se')
boxplot(data['texture_se'])
displot(data['texture_se'])
# Out:
# (-0.12625000000000008, 2.43415)
# There are about 0 outliers below the lower limit.
# There are about 20 outliers above the upper limit.
# There are about 20 outliers in total.

# %% [markdown]
# ### 'perimeter_se'
# -

# %%
print(limits(data['perimeter_se']))
how_many_outliers(data,'perimeter_se')
boxplot(data['perimeter_se'])
displot(data['perimeter_se'])
# Out:
# (-1.0205, 5.9835)
# There are about 0 outliers below the lower limit.
# There are about 38 outliers above the upper limit.
# There are about 38 outliers in total.

# %% [markdown]
# ### 'area_se'
# -

# %%
print(limits(data['area_se']))
how_many_outliers(data,'area_se')
boxplot(data['area_se'])
displot(data['area_se'])
# Out:
# (-23.15999999999999, 86.19999999999999)
# There are about 0 outliers below the lower limit.
# There are about 65 outliers above the upper limit.
# There are about 65 outliers in total.

# %% [markdown]
# ### 'smoothness_se'
# - standard error for local variation in radius lengths

# %%
print(limits(data['smoothness_se']))
how_many_outliers(data,'smoothness_se')
boxplot(data['smoothness_se'])
displot(data['smoothness_se'])
# Out:
# (0.0007034999999999993, 0.012611500000000001)
# There are about 0 outliers below the lower limit.
# There are about 30 outliers above the upper limit.
# There are about 30 outliers in total.

# %% [markdown]
# ### 'compactness_se'
# - standard error for perimeter^2 / area - 1.0

# %%
print(limits(data['compactness_se']))
how_many_outliers(data,'compactness_se')
boxplot(data['compactness_se'])
displot(data['compactness_se'])
# Out:
# (-0.015974999999999996, 0.061505)
# There are about 0 outliers below the lower limit.
# There are about 28 outliers above the upper limit.
# There are about 28 outliers in total.

# %% [markdown]
# ### 'concavity_se'
# - standard error for severity of concave portions of the contour

# %%
print(limits(data['concavity_se']))
how_many_outliers(data,'concavity_se')
boxplot(data['concavity_se'])
displot(data['concavity_se'])
# Out:
# (-0.025349999999999998, 0.08249)
# There are about 0 outliers below the lower limit.
# There are about 22 outliers above the upper limit.
# There are about 22 outliers in total.

# %% [markdown]
# ### 'concave points_se'
# - standard error for number of concave portions of the contour

# %%
print(limits(data['concave points_se']))
how_many_outliers(data,'concave points_se')
boxplot(data['concave points_se'])
displot(data['concave points_se'])
# Out:
# (-0.0029700000000000013, 0.025318)
# There are about 0 outliers below the lower limit.
# There are about 19 outliers above the upper limit.
# There are about 19 outliers in total.

# %% [markdown]
# ### 'symmetry_se'
# -

# %%
print(limits(data['symmetry_se']))
how_many_outliers(data,'symmetry_se')
boxplot(data['symmetry_se'])
displot(data['symmetry_se'])
# Out:
# (0.0026799999999999984, 0.035960000000000006)
# There are about 0 outliers below the lower limit.
# There are about 27 outliers above the upper limit.
# There are about 27 outliers in total.

# %% [markdown]
# ### 'fractal_dimension_se'
# - standard error for "coastline approximation" - 1

# %%
print(limits(data['fractal_dimension_se']))
how_many_outliers(data,'fractal_dimension_se')
boxplot(data['fractal_dimension_se'])
displot(data['fractal_dimension_se'])
# Out:
# (-0.0012170000000000006, 0.008023)
# There are about 0 outliers below the lower limit.
# There are about 28 outliers above the upper limit.
# There are about 28 outliers in total.

# %% [markdown]
# ### 'radius_worst'
# - "worst" or largest mean value for mean of distances from center to points on the perimeter

# %%
print(limits(data['radius_worst']))
how_many_outliers(data,'radius_worst')
boxplot(data['radius_worst'])
displot(data['radius_worst'])
# Out:
# (4.340000000000002, 27.459999999999997)
# There are about 0 outliers below the lower limit.
# There are about 17 outliers above the upper limit.
# There are about 17 outliers in total.

# %% [markdown]
# ### 'texture_worst'
# - "worst" or largest mean value for standard deviation of gray-scale values

# %%
print(limits(data['texture_worst']))
how_many_outliers(data,'texture_worst')
boxplot(data['texture_worst'])
displot(data['texture_worst'])
# Out:
# (8.119999999999997, 42.68)
# There are about 0 outliers below the lower limit.
# There are about 5 outliers above the upper limit.
# There are about 5 outliers in total.

# %% [markdown]
# ### 'perimeter_worst'
# -

# %%
print(limits(data['perimeter_worst']))
how_many_outliers(data,'perimeter_worst')
boxplot(data['perimeter_worst'])
displot(data['perimeter_worst'])
# Out:
# (22.17499999999999, 187.335)
# There are about 0 outliers below the lower limit.
# There are about 15 outliers above the upper limit.
# There are about 15 outliers in total.

# %% [markdown]
# ### 'area_worst'
# -

# %%
print(limits(data['area_worst']))
how_many_outliers(data,'area_worst')
boxplot(data['area_worst'])
displot(data['area_worst'])
# Out:
# (-337.7500000000001, 1937.0500000000002)
# There are about 0 outliers below the lower limit.
# There are about 35 outliers above the upper limit.
# There are about 35 outliers in total.

# %% [markdown]
# ### 'smoothness_worst'
# - "worst" or largest mean value for local variation in radius lengths

# %%
print(limits(data['smoothness_worst']))
how_many_outliers(data,'smoothness_worst')
boxplot(data['smoothness_worst'])
displot(data['smoothness_worst'])
# Out:
# (0.07250000000000001, 0.1901)
# There are about 1 outliers below the lower limit.
# There are about 6 outliers above the upper limit.
# There are about 7 outliers in total.

# %% [markdown]
# ### 'compactness_worst'
# - "worst" or largest mean value for perimeter^2 / area - 1.0

# %%
print(limits(data['compactness_worst']))
how_many_outliers(data,'compactness_worst')
boxplot(data['compactness_worst'])
displot(data['compactness_worst'])
# Out:
# (-0.14065000000000005, 0.6269500000000001)
# There are about 0 outliers below the lower limit.
# There are about 16 outliers above the upper limit.
# There are about 16 outliers in total.

# %% [markdown]
# ### 'concavity_worst  '
# - "worst" or largest mean value for severity of concave portions of the contour

# %%
print(limits(data['concavity_worst']))
how_many_outliers(data,'concavity_worst')
boxplot(data['concavity_worst'])
displot(data['concavity_worst'])
# Out:
# (-0.2881000000000001, 0.7855000000000001)
# There are about 0 outliers below the lower limit.
# There are about 12 outliers above the upper limit.
# There are about 12 outliers in total.

# %% [markdown]
# ### 'concave points_worst'
# - "worst" or largest mean value for number of concave portions of the contour

# %%
print(limits(data['concave points_worst']))
how_many_outliers(data,'concave points_worst')
boxplot(data['concave points_worst'])
displot(data['concave points_worst'])
# Out:
# (-0.07977499999999997, 0.30610499999999996)
# There are about 0 outliers below the lower limit.
# There are about 0 outliers above the upper limit.
# There are about 0 outliers in total.

# %% [markdown]
# ### 'symmetry_worst '
# -

# %%
print(limits(data['symmetry_worst']))
how_many_outliers(data,'symmetry_worst')
boxplot(data['symmetry_worst'])
displot(data['symmetry_worst'])
# Out:
# (0.14915, 0.41915)
# There are about 0 outliers below the lower limit.
# There are about 23 outliers above the upper limit.
# There are about 23 outliers in total.

# %% [markdown]
# ### 'fractal_dimension_worst'
# - "worst" or largest mean value for "coastline approximation" - 1

# %%
print(limits(data['fractal_dimension_worst']))
how_many_outliers(data,'fractal_dimension_worst')
boxplot(data['fractal_dimension_worst'])
displot(data['fractal_dimension_worst'])
# Out:
# (0.04053, 0.12301)
# There are about 0 outliers below the lower limit.
# There are about 24 outliers above the upper limit.
# There are about 24 outliers in total.

# %% [markdown]
# - As we can see, the column with the most outliers is 'area_se'. In second place we have a tie between the columns 'radius_se' and 'perimeter_se'. I will remove the outliers from the 'area_se' and 'perimeter_se' columns and remove the 'radius_se' column from our data, due to the extremely high correlation with the 'perimeter_se' variable (greater than 97%) and also because it has a higher correlation with the our target variable, if we compare the two that tied (56.71% X 55.61%).

# %%
how_many_outliers(data, 'area_se')
# Out:
# There are about 0 outliers below the lower limit.
# There are about 65 outliers above the upper limit.
# There are about 65 outliers in total.

# %%
how_many_outliers(data, 'radius_se')
# Out:
# There are about 0 outliers below the lower limit.
# There are about 38 outliers above the upper limit.
# There are about 38 outliers in total.

# %%
how_many_outliers(data, 'perimeter_se')
# Out:
# There are about 0 outliers below the lower limit.
# There are about 38 outliers above the upper limit.
# There are about 38 outliers in total.

# %%
correlation = data['radius_se'].corr(data['perimeter_se'])
print(f'The correlation between "radius_se" and "perimeter_se" is: {correlation:.5%}')
# Out:
# The correlation between "radius_se" and "perimeter_se" is: 97.27937%

# %%
print(f"radius_se X diagnosis: {data['radius_se'].corr(data_copy['diagnosis']):.5%}")
print(f"perimeter_se X diagnosis: {data['perimeter_se'].corr(data_copy['diagnosis']):.5%}")
# Out:
# radius_se X diagnosis: 56.71338%
# perimeter_se X diagnosis: 55.61407%

# %%
data.drop('radius_se', axis=1, inplace=True)
data.shape
# Out:
# (569, 30)

# %%
data, outliers_removed = remove_outliers(data, 'area_se')
print(f'{outliers_removed} outliers removed.')
# Out:
# 65 outliers removed.

# %%
data, outliers_removed = remove_outliers(data, 'perimeter_se')
print(f'{outliers_removed} outliers removed.')
# Out:
# 10 outliers removed.

# %%
for column in data.columns:
    if column == 'diagnosis':
        continue
    inf, sup, total = how_many_outliers(data, column)
    print(f'{column}: {total} outliers.')
# Out:
# radius_mean: 14 outliers.
# texture_mean: 7 outliers.
# perimeter_mean: 13 outliers.
# area_mean: 25 outliers.
# smoothness_mean: 6 outliers.
# compactness_mean: 16 outliers.
# concavity_mean: 18 outliers.
# concave points_mean: 10 outliers.
# symmetry_mean: 15 outliers.
# fractal_dimension_mean: 15 outliers.
# radius_se: 38 outliers.
# texture_se: 20 outliers.
# perimeter_se: 38 outliers.
# area_se: 65 outliers.
# smoothness_se: 30 outliers.
# compactness_se: 28 outliers.
# concavity_se: 22 outliers.
# concave points_se: 19 outliers.
# symmetry_se: 27 outliers.
# fractal_dimension_se: 28 outliers.
# radius_worst: 17 outliers.
# texture_worst: 5 outliers.
# perimeter_worst: 15 outliers.
# area_worst: 35 outliers.
# smoothness_worst: 7 outliers.
# compactness_worst: 16 outliers.
# concavity_worst: 12 outliers.
# concave points_worst: 0 outliers.
# symmetry_worst: 23 outliers.
# fractal_dimension_worst: 24 outliers.

# %%
def how_many_outliers(df, column):
    inf_lim, sup_lim = limits(df[column])
    inf = df.loc[df[column] < inf_lim].shape[0]
    sup = df.loc[df[column] > sup_lim].shape[0]
    total = inf + sup
    return inf, sup, total  # Retorna os resultados como uma tupla

# %% [markdown]
# ### Encoding
# - Now let's convert categorical data into a numerical format that can be used by our machine learning algorithms.

# %% [markdown]
# ### Dealing with categorical data

# %%
cat_cols
# Out:
# Index(['diagnosis'], dtype='object')

# %%
data['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
data['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
# OneHot Encoding
data = pd.get_dummies(data=data, drop_first=True)

# %%
data.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  \
# ...

# %% [markdown]
# ### Countplot

# %%
sns.countplot(data['diagnosis_M'])
plt.show()
# Out:
# C:\Users\Henrique\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data['diagnosis_M'].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis_M, dtype: int64

# %% [markdown]
# ### Correlation matrix and heatmap

# %%
data2 = data.drop('diagnosis_M', axis=1)

# %%
data2.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  \
# ...

# %%
data2.corrwith(data['diagnosis_M']).plot.bar(
    figsize=(20,10), title='Correlated with diagnosis_M', rot=45, grid=True
);

# %%
# Correlation matrix
corr = data.corr()

# %%
corr
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     1.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      1.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        1.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# ...

# %%
# Heatmap
plt.figure(figsize=(20,15))
sns.heatmap(corr, annot=True, linewidth=1);

# %% [markdown]
# ### Splitting the dataset

# %%
data.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  \
# ...

# %%
# Matrix of features - indenpendent variables
X = data.iloc[:, 1:-1].values

# %%
X.shape
# Out:
# (569, 30)

# %%
# Target variable - dependent variable
y = data.iloc[:, -1]

# %%
y.shape
# Out:
# (569,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.shape
# Out:
# (455, 30)

# %%
X_test.shape
# Out:
# (114, 30)

# %%
y_train.shape
# Out:
# (455,)

# %%
y_test.shape
# Out:
# (114,)

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
standard_scaler = StandardScaler()

# %%
X_train = standard_scaler.fit_transform(X_train)
X_test = standard_scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-1.15036482, -0.39064196, -1.12855021, ..., -0.75798367,
#         -0.01614761, -0.38503402],
#        [-0.93798972,  0.68051405, -0.94820146, ..., -0.60687023,
#          0.09669004, -0.38615797],
#        [ 0.574121  , -1.03333557,  0.51394098, ..., -0.02371948,
#         -0.20050207, -0.75144254],
#        ...,
#        [-1.32422924, -0.20048168, -1.31754581, ..., -0.97974953,
#         -0.71542314, -0.11978123],
#        [-1.24380987, -0.2245526 , -1.28007609, ..., -1.75401433,
#         -1.58157125, -1.00601779],
#        [-0.73694129,  1.14989702, -0.71226578, ..., -0.27460457,
#         -1.25895095,  0.21515662]])

# %%
X_test
# Out:
# array([[-0.20175604,  0.3290786 , -0.13086754, ...,  1.3893291 ,
#          1.08203284,  1.54029664],
#        [-0.25555773,  1.46763319, -0.31780437, ..., -0.83369364,
#         -0.73131577, -0.87732522],
#        [-0.02619262, -0.8407682 , -0.09175081, ..., -0.49483785,
#         -1.22080864, -0.92115937],
#        ...,
#        [ 1.71811488,  0.09318356,  1.7286186 , ...,  1.57630515,
#          0.20317063, -0.15406178],
#        [ 1.18859296,  0.34352115,  1.19333694, ...,  0.56019755,
#          0.26991966, -0.27320074],
#        [ 0.26263752, -0.58080224,  0.28459338, ..., -0.19383705,
#         -1.15564888,  0.11231497]])

# %% [markdown]
# ## Building the model

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic_regressor = LogisticRegression(random_state=0)

# %%
logistic_regressor.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = logistic_regressor.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix

# %%
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# %%
results = pd.DataFrame([['Logistic Regression', acc, f1, precision, recall]], 
                       columns =['Model', 'Accuracy', 'F1 Score', 'Precision', 'Recall'])

# %%
results
# Out:
#                  Model  Accuracy  F1 Score  Precision    Recall
# 0  Logistic Regression  0.964912  0.957447   0.957447  0.957447

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[65  2]
#  [ 2 45]]

# %% [markdown]
# ### Cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
accuracies = cross_val_score(logistic_regressor, X_train, y_train, cv=10)

# %%
print(f'Accuracy is {accuracies.mean():.2%}')
print(f'Standard Deviation in {accuracies.std():.2%}')
# Out:
# Accuracy is 97.81%
# Standard Deviation in 1.98%

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
random_forest = RandomForestClassifier(random_state=0)
random_forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_pred = random_forest.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix

# %%
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# %%
results_rf = pd.DataFrame([['Random Forest', acc, f1, precision, recall]], 
                       columns =['Model', 'Accuracy', 'F1 Score', 'Precision', 'Recall'])

# %%
results = results.append(results_rf, ignore_index=True)
# Out:
# C:\Users\Henrique\AppData\Local\Temp\ipykernel_11348\3329811712.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(results_rf, ignore_index=True)

# %%
results
# Out:
#                  Model  Accuracy  F1 Score  Precision    Recall
# 0  Logistic Regression  0.964912  0.957447   0.957447  0.957447
# 1        Random Forest  0.964912  0.958333   0.938776  0.978723

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[64  3]
#  [ 1 46]]

# %% [markdown]
# ### Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
accuracies = cross_val_score(random_forest, X_train, y_train, cv=10)

# %%
print(f'Accuracy is {accuracies.mean():.2%}')
print(f'Standard Deviation in {accuracies.std():.2%}')
# Out:
# Accuracy is 96.05%
# Standard Deviation in 3.07%

# %% [markdown]
# ### Randomized Search to find the best parameters (Logistic Regression)

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
param_distributions = {'penalty':['l1', 'l2', 'elasticnet', None],
              'C':[0.25, 0.5, 0.75, 1.0, 1.25, 1.5, 1.75, 2.0],
              'solver':['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga'] 
}

# %%
param_distributions
# Out:
# {'penalty': ['l1', 'l2', 'elasticnet', None],
#  'C': [0.25, 0.5, 0.75, 1.0, 1.25, 1.5, 1.75, 2.0],
#  'solver': ['lbfgs',
#   'liblinear',
#   'newton-cg',
#   'newton-cholesky',
#   'sag',
#   'saga']}

# %%
random_search = RandomizedSearchCV(logistic_regressor, param_distributions=param_distributions, n_iter=10, scoring='roc_auc', n_jobs=3, cv=2, verbose=3)

# %%
random_search.fit(X_train, y_train)
# Out:
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
# C:\Users\Henrique\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 14 fits failed out of a total of 20.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Henrique\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Henrique\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
# ...

# %%
random_search.best_estimator_
# Out:
# LogisticRegression(C=1.75, random_state=0, solver='sag')

# %%
random_search.best_score_
# Out:
# 0.9936719122072816

# %%
random_search.best_params_
# Out:
# {'solver': 'sag', 'penalty': 'l2', 'C': 1.75}

# %% [markdown]
# ## Final model (Logistic Regression)

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier = LogisticRegression(C=1.75, random_state=0, solver='sag')
classifier.fit(X_train, y_train)
# Out:
# C:\Users\Henrique\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# LogisticRegression(C=1.75, random_state=0, solver='sag')

# %%
y_pred = classifier.predict(X_test)

# %%
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

model_results = pd.DataFrame([['Final Logistic Regression', acc, f1, precision, recall]], 
                       columns =['Model', 'Accuracy', 'F1 Score', 'Precision', 'Recall'])

results = results.append(model_results, ignore_index=True)
results
# Out:
# C:\Users\Henrique\AppData\Local\Temp\ipykernel_11348\2681062239.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(model_results, ignore_index=True)
#                        Model  Accuracy  F1 Score  Precision    Recall
# 0        Logistic Regression  0.964912  0.957447   0.957447  0.957447
# 1              Random Forest  0.964912  0.958333   0.938776  0.978723
# 2  Final Logistic Regression  0.964912  0.957447   0.957447  0.957447

# %% [markdown]
# ### Cross Validation

# %%
from sklearn.model_selection import cross_val_score

accuracies = cross_val_score(classifier, X_train, y_train, cv=10)

print(f'Accuracy is {accuracies.mean():.2%}')
print(f'Standard Deviation in {accuracies.std():.2%}')
# Out:
# C:\Users\Henrique\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Henrique\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Henrique\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Henrique\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Henrique\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %% [markdown]
# ### Predicting a single observation

# %%
data.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  \
# ...

# %%
# You need '[[]]' because it is an ARRAY
single_obs = [[17.99, 10.38, 122.80, 1001.0, 0.11840, 0.27760, 0.3001, 0.14710, 0.2419, 0.07871, 1.0950, 0.9053, 8.589, 153.40, 0.006399, 0.04904, 0.05373, 0.01587, 0.03003, 0.006193, 25.38, 17.33, 184.60, 2019.0, 0.1622, 0.6656, 0.7119, 0.2654, 0.4601, 0.11890]]

# %%
single_obs
# Out:
# [[17.99,
#   10.38,
#   122.8,
#   1001.0,
#   0.1184,
#   0.2776,
#   0.3001,
#   0.1471,
#   0.2419,
#   0.07871,
#   1.095,
#   0.9053,
#   8.589,
#   153.4,
#   0.006399,
#   0.04904,
#   0.05373,
#   0.01587,
#   0.03003,
#   0.006193,
#   25.38,
#   17.33,
#   184.6,
#   2019.0,
#   0.1622,
#   0.6656,
#   0.7119,
#   0.2654,
#   0.4601,
#   0.1189]]

# %%
classifier.predict(standard_scaler.transform(single_obs))
# Out:
# array([1], dtype=uint8)
